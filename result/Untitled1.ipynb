# %%
# !python train.py \
  --data "METR-LA_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 64 \
  --mape_epsilon 1.0 \
  --num_layers 3 \
  --save_path "DG_TVCRN_run1_embed_dim_16_hiddden_dim_64_layers_3.pth"
# Out:
# ^C

# %%
# !python test_final.py \
  --data METR-LA_processed.npz \
  --checkpoint DG_TVCRN_run1_embed_dim_16_hiddden_dim_64_layers_3.pth \
  --num_layers 3 \
  --embed_dim 16 \
  --hidden_dim 64
# Out:
# 🚀 正在使用设备: cuda:0
#
# 📂 正在加载数据: METR-LA_processed.npz ...
# 正在从 'METR-LA_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([23967, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([23967, 12, 207, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([3404, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([3404, 12, 207, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([6832, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([6832, 12, 207, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 374
#   验证集 batches: 54
#   测试集 batches: 107
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 207]), Std shape=torch.Size([1, 207])
# 📊 测试集样本数: 6832
# 🏗️ 正在构建模型 (Hidden: 64, Embed: 16)...
# ✓ 模型构建完成: ResidualMLPDecoder
# 📥 正在加载权重: DG_TVCRN_run1_embed_dim_16_hiddden_dim_64_layers_3.pth ...
# ✅ 成功加载 Checkpoint (Epoch 51, Val MAE: 2.7308)
#
# runing 推理中...
# ...

# %%
# !python train.py \
  --data "PEMS-BAY_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 64 \
  --mape_epsilon 1.0 \
  --num_layers 3 \
  --save_path "DG_TVCRN_run2_embed_dim_16_hiddden_dim_64_layers_3.pth"
# ============================================================
# --- 最终测试结果 (最佳模型) ---
# ============================================================
#   [Overall] MAE: 1.6660 | MAPE: 3.81% | RMSE: 3.4642
#   [15 min]  MAE: 1.3650 | MAPE: 2.93% | RMSE: 2.6677
#   [30 min]  MAE: 1.7282 | MAPE: 3.99% | RMSE: 3.5580
#   [60 min]  MAE: 2.0686 | MAPE: 4.90% | RMSE: 4.2133
# ============================================================
# Out:
# ^C

# %%
# !python train.py \
  --data "METR-LA_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 64 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run1_embed_dim_16_hiddden_dim_64_layers_1.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'METR-LA_processed.npz' 加载数据...
# 正在从 'METR-LA_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([23967, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([23967, 12, 207, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([3404, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([3404, 12, 207, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([6832, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([6832, 12, 207, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 374
#   验证集 batches: 54
#   测试集 batches: 107
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 207]), Std shape=torch.Size([1, 207])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 207])
#   - Scaler Std 形状: torch.Size([1, 207])
#   - 训练集真实值范围: [1.78, 70.00]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 41,372
#
# ...

# %%
# !python train.py \
  --data "PEMS-BAY_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 64 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run2_embed_dim_16_hiddden_dim_64_layers_1.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 569
#   验证集 batches: 82
#   测试集 batches: 163
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 325]), Std shape=torch.Size([1, 325])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 325])
#   - Scaler Std 形状: torch.Size([1, 325])
#   - 训练集真实值范围: [3.00, 85.10]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 45,148
#
# ...

# %%
# !python train.py \
  --data "METR-LA_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 64 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run1_embed_dim_16_hiddden_dim_64_layers_1_2.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'METR-LA_processed.npz' 加载数据...
# 正在从 'METR-LA_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([23967, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([23967, 12, 207, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([3404, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([3404, 12, 207, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([6832, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([6832, 12, 207, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 374
#   验证集 batches: 54
#   测试集 batches: 107
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 207]), Std shape=torch.Size([1, 207])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 207])
#   - Scaler Std 形状: torch.Size([1, 207])
#   - 训练集真实值范围: [1.00, 70.00]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 41,372
#
# ...

# %%
# !python train.py \
  --data "PEMS-BAY_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 64 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run2_embed_dim_16_hiddden_dim_64_layers_1_2.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 569
#   验证集 batches: 82
#   测试集 batches: 163
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 325]), Std shape=torch.Size([1, 325])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 325])
#   - Scaler Std 形状: torch.Size([1, 325])
#   - 训练集真实值范围: [5.50, 82.10]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 45,148
#
# ...

# %%
# !python train.py \
  --data "METR-LA_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 128 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run1_embed_dim_16_hiddden_dim_128_layers_1.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'METR-LA_processed.npz' 加载数据...
# 正在从 'METR-LA_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([23967, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([23967, 12, 207, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([3404, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([3404, 12, 207, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([6832, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([6832, 12, 207, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 374
#   验证集 batches: 54
#   测试集 batches: 107
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 207]), Std shape=torch.Size([1, 207])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 207])
#   - Scaler Std 形状: torch.Size([1, 207])
#   - 训练集真实值范围: [1.00, 70.00]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 93,500
#
# ...

# %%
# !python train.py \
  --data "PEMS-BAY_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 128 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run2_embed_dim_16_hiddden_dim_128_layers_1.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 569
#   验证集 batches: 82
#   测试集 batches: 163
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 325]), Std shape=torch.Size([1, 325])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 325])
#   - Scaler Std 形状: torch.Size([1, 325])
#   - 训练集真实值范围: [3.10, 81.00]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 97,276
#
# ...

# %%
# !python train.py \
  --data "METR-LA_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 32 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run1_embed_dim_16_hiddden_dim_32_layers_1.pth"
# =============================================
# -- -- 最终测试结果（最佳模型）-- --
# =============================================
# [Overall] MAE: 2.9463 | MAPE: 8.14% | RMSE: 5.7235
# [15 min] MAE: 2.5500 | MAPE: 6.66% | RMSE: 4.8046
# [30 min] MAE: 2.9663 | MAPE: 8.21% | RMSE: 5.7327
# [60 min] MAE: 3.5277 | MAPE: 10.27% | RMSE: 6.8182
# =============================================
# Out:
# ^C
# Traceback (most recent call last):
#   File "/data/v8.0/train.py", line 1, in <module>
#     import torch
#   File "/opt/conda/lib/python3.10/site-packages/torch/__init__.py", line 405, in <module>
#     from torch._C import *  # noqa: F403
#   File "<frozen importlib._bootstrap>", line 216, in _lock_unlock_module
# KeyboardInterrupt

# %%
# !python train.py \
  --data "PEMS-BAY_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 32 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run2_embed_dim_16_hiddden_dim_32_layers_1.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 569
#   验证集 batches: 82
#   测试集 batches: 163
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 325]), Std shape=torch.Size([1, 325])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 325])
#   - Scaler Std 形状: torch.Size([1, 325])
#   - 训练集真实值范围: [3.20, 81.20]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 29,068
#
# ...

# %%
# !python train.py \
  --data "METR-LA_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 16 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run1_embed_dim_16_hiddden_dim_16_layers_1.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'METR-LA_processed.npz' 加载数据...
# 正在从 'METR-LA_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([23967, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([23967, 12, 207, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([3404, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([3404, 12, 207, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([6832, 12, 207, 1])
#   Y 形状 (PyTorch 张量): torch.Size([6832, 12, 207, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 374
#   验证集 batches: 54
#   测试集 batches: 107
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 207]), Std shape=torch.Size([1, 207])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 207])
#   - Scaler Std 形状: torch.Size([1, 207])
#   - 训练集真实值范围: [1.00, 70.00]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 19,748
#
# ...

# %%
# !python train.py \
  --data "PEMS-BAY_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 16 \
  --hidden_dim 16 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run2_embed_dim_16_hiddden_dim_16_layers_1.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 569
#   验证集 batches: 82
#   测试集 batches: 163
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 325]), Std shape=torch.Size([1, 325])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 325])
#   - Scaler Std 形状: torch.Size([1, 325])
#   - 训练集真实值范围: [4.90, 81.10]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 23,524
#
# ...

# %%
# !python train.py \
  --data "PEMS-BAY_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 32 \
  --hidden_dim 64 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run2_embed_dim_32_hiddden_dim_64_layers_1.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 569
#   验证集 batches: 82
#   测试集 batches: 163
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 325]), Std shape=torch.Size([1, 325])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 325])
#   - Scaler Std 形状: torch.Size([1, 325])
#   - 训练集真实值范围: [3.40, 81.20]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 57,660
#
# ...

# %%
# !python train.py \
  --data "PEMS-BAY_processed.npz" \
  --batch_size 64 \
  --lr 0.002 \
  --embed_dim 8 \
  --hidden_dim 64 \
  --mape_epsilon 1.0 \
  --num_layers 1 \
  --save_path "DG_TVCRN_run2_embed_dim_8_hiddden_dim_64_layers_1.pth"
# Out:
# 正在使用设备: cuda
#
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在从 'PEMS-BAY_processed.npz' 加载数据...
# 正在为 'train' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([36458, 12, 325, 1])
# 初始化完成。
# 正在为 'val' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([5188, 12, 325, 1])
# 初始化完成。
# 正在为 'test' 初始化 TrafficDataset...
#   X 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
#   Y 形状 (PyTorch 张量): torch.Size([10401, 12, 325, 1])
# 初始化完成。
#
# 正在创建 DataLoaders...
#   训练集 batches: 569
#   验证集 batches: 82
#   测试集 batches: 163
#
# PerNodeScaler 已创建: Mean shape=torch.Size([1, 325]), Std shape=torch.Size([1, 325])
#
# ...
# 数据统计信息:
#   - Scaler Mean 形状: torch.Size([1, 325])
#   - Scaler Std 形状: torch.Size([1, 325])
#   - 训练集真实值范围: [3.30, 81.40]
#   - MAPE Epsilon: 1.0 (过滤掉小于此值的样本)
# ...
#
# 正在构建模型...
# ✓ 模型构建完成: ResidualMLPDecoder
# 模型参数量: 38,892
#
# ...
